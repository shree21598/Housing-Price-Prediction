# %% [markdown]
# Problem 5

# %%
import pandas as pd

data = pd.read_csv("housing_data.csv")

len_dataset = len(data)
print("Number of entries: ", len_dataset)
# Out:
# Number of entries:  1460

# %%
no_missing_data = data.isnull().sum().sum()
print("Number of missing values: ", no_missing_data)
# Out:
# Number of missing values:  6965

# %%
attr_target_corr = data.corr().sort_values(by='SalePrice',ascending = False)
attr_target_corr = abs(attr_target_corr["SalePrice"])
attr_target_corr.sort_values(ascending=False)
attr_target_corr[1:11]
# Out:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %%
import seaborn as sns
sns.scatterplot(data=data, x="OverallQual", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.scatterplot(data=data, x="GrLivArea", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
sns.scatterplot(data=data, x="GarageCars", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='GarageCars', ylabel='SalePrice'>

# %%
sns.scatterplot(data=data, x="GarageArea", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %%
sns.scatterplot(data=data, x="TotalBsmtSF", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
sns.scatterplot(data=data, x="1stFlrSF", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='1stFlrSF', ylabel='SalePrice'>

# %%
sns.scatterplot(data=data, x="FullBath", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='FullBath', ylabel='SalePrice'>

# %%
sns.scatterplot(data=data, x="TotRmsAbvGrd", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='TotRmsAbvGrd', ylabel='SalePrice'>

# %%
sns.scatterplot(data=data, x="YearBuilt", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
sns.scatterplot(data=data, x="YearRemodAdd", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='SalePrice'>

# %%
All of the ten attributes have positive correlation with the target attribute "SalePrice" meaning A positive correlation indicates the extent to which those variables increase or decrease in parallel
# Out:
#   Input In [16]
#     All of the ten attributes have positive correlation with the target attribute "SalePrice" meaning A positive correlation indicates the extent to which those variables increase or decrease in parallel
#         ^
# SyntaxError: invalid syntax

# %%
sns.barplot(data=data, x="OverallQual", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.barplot(data=data, x="GrLivArea", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
sns.barplot(data=data, x="GarageCars", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='GarageCars', ylabel='SalePrice'>

# %%
sns.barplot(data=data, x="GarageArea", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %%
sns.barplot(data=data, x="TotalBsmtSF", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
sns.barplot(data=data, x="1stFlrSF", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='1stFlrSF', ylabel='SalePrice'>

# %%
sns.barplot(data=data, x="FullBath", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='FullBath', ylabel='SalePrice'>

# %%
sns.barplot(data=data, x="TotRmsAbvGrd", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='TotRmsAbvGrd', ylabel='SalePrice'>

# %%
sns.barplot(data=data, x="YearBuilt", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
sns.barplot(data=data, x="YearRemodAdd", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='SalePrice'>

# %% [markdown]
# Problem 2

# %%
import numpy as np
from scipy.spatial.distance import pdist
n = 150
fm = []
for m in range(1,101):
    temp = []
    distance_average = []
    for i in range(3):
        data = np.random.uniform(0, 1, (n, m))
        euc_dist = pdist(data, metric='euclidean')
        temp.append(euc_dist)
    for i in range(len(temp[0])):
        total_dist = 0
        for j in range(len(temp)):
            total_dist += temp[j][i]
        distance_average.append(total_dist / len(temp))
    dist_max = np.max(distance_average)
    dist_min = np.min(distance_average)
    fm.append(np.log10((dist_max - dist_min) / dist_min))
value_m = np.arange(1, 101)
plt.scatter(value_m, fm)
plt.title("Curse of Dimensionality when n = 150")
plt.xlabel("m")
plt.ylabel("f(m)")
# Out:
# Text(0, 0.5, 'f(m)')

# %%
import numpy as np
from scipy.spatial.distance import pdist
n = 1500
fm = []
for m in range(1,101):
    temp = []
    distance_average = []
    for i in range(3):
        data = np.random.uniform(0, 1, (n, m))
        euc_dist = pdist(data, metric='euclidean')
        temp.append(euc_dist)
    for i in range(len(temp[0])):
        total_dist = 0
        for j in range(len(temp)):
            total_dist += temp[j][i]
        distance_average.append(total_dist / len(temp))
    dist_max = np.max(distance_average)
    dist_min = np.min(distance_average)
    fm.append(np.log10((dist_max - dist_min) / dist_min))
value_m = np.arange(1, 101)
plt.scatter(value_m, fm)
plt.title("Curse of Dimensionality when n = 1500")
plt.xlabel("m")
plt.ylabel("f(m)")
# Out:
# Text(0, 0.5, 'f(m)')

# %%
import numpy as np
from scipy.spatial.distance import pdist
n = 15000
fm = []
for m in range(1,101):
    temp = []
    distance_average = []
    for i in range(3):
        data = np.random.uniform(0, 1, (n, m))
        euc_dist = pdist(data, metric='euclidean')
        temp.append(euc_dist)
    for i in range(len(temp[0])):
        total_dist = 0
        for j in range(len(temp)):
            total_dist += temp[j][i]
        distance_average.append(total_dist / len(temp))
    dist_max = np.max(distance_average)
    dist_min = np.min(distance_average)
    fm.append(np.log10((dist_max - dist_min) / dist_min))
value_m = np.arange(1, 101)
plt.scatter(value_m, fm)
plt.title("Curse of Dimensionality when n = 15000")
plt.xlabel("m")
plt.ylabel("f(m)")
